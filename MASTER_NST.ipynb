# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
import os 
os.chdir("/content/drive/My Drive/Group_Project")
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms

from __future__ import print_function
import PIL.Image as Image
import matplotlib.pyplot as plt
import copy
import numpy as np

use_cuda = torch.cuda.is_available()
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor

# %% [markdown]
# The following code for the NST algorithm was referenced from the work of
# Sunghyun (psh01087) on GitHub.

# %%
imsize = 256 if use_cuda else 128

transform = transforms.Compose([transforms.Resize([imsize,imsize]), transforms.ToTensor()])

def image_loader(image_name, transform=None, max_size=None, shape=None):
    image = Image.open(image_name).convert('RGB')
    
    if max_size is not None:
        scale = max_size / max(image.size)
        size = np.array(image.size) * scale
        image = image.resize(size.astype(int), Image.ANTIALIAS)
    
    if shape is not None:
        image = image.resize(shape, Image.LANCZOS)
    
    if transform is not None:
        image = transform(image)
        
    image = Variable(image)
    image = image.unsqueeze(0)
    
    return image.type(dtype)

# %%
class ContentLoss(nn.Module):

    def __init__(self, target, weight):
        super(ContentLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.loss = self.criterion(input * self.weight, self.target)
        self.output = input
        return self.output

    def backward(self, retain_graph=True):
        self.loss.backward(retain_graph=retain_graph)
        return self.loss

# %%
class GramMatrix(nn.Module):

    def forward(self, input):
        a, b, c, d = input.size()
        features = input.view(a * b, c * d)
        G = torch.mm(features, features.t())
        return G.div(a * b * c * d)

# %%
class StyleLoss(nn.Module):

    def __init__(self, target, weight):
        super(StyleLoss, self).__init__()
        self.target = target.detach() * weight
        self.weight = weight
        self.gram = GramMatrix()
        self.criterion = nn.MSELoss()

    def forward(self, input):
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.criterion(self.G, self.target)
        return self.output

    def backward(self, retain_graph=True):
        self.loss.backward(retain_graph=retain_graph)
        return self.loss

# %%
cnn = models.vgg19(pretrained=True).features

# move it to the GPU if possible:
if use_cuda:
    cnn = cnn.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']


def get_style_model_and_losses(cnn, style_img, content_img,
                               style_weight=2000, content_weight=1,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    cnn = copy.deepcopy(cnn)

    # just in order to have an iterable access to or list of content/syle
    # losses
    content_losses = []
    style_losses = []

    model = nn.Sequential()  # the new Sequential module network
    gram = GramMatrix()  # we need a gram module in order to compute style targets

    # move these modules to the GPU if possible:
    if use_cuda:
        model = model.cuda()
        gram = gram.cuda()

    i = 1
    for layer in list(cnn):
        if isinstance(layer, nn.Conv2d):
            name = "conv_" + str(i)
            model.add_module(name, layer)

            if name in content_layers:
                # add content loss:
                target = model(content_img).clone()
                content_loss = ContentLoss(target, content_weight)
                model.add_module("content_loss_" + str(i), content_loss)
                content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

        if isinstance(layer, nn.ReLU):
            name = "relu_" + str(i)
            model.add_module(name, layer)

            if name in content_layers:
                # add content loss:
                target = model(content_img).clone()
                content_loss = ContentLoss(target, content_weight)
                model.add_module("content_loss_" + str(i), content_loss)
                content_losses.append(content_loss)

            if name in style_layers:
                # add style loss:
                target_feature = model(style_img).clone()
                target_feature_gram = gram(target_feature)
                style_loss = StyleLoss(target_feature_gram, style_weight)
                model.add_module("style_loss_" + str(i), style_loss)
                style_losses.append(style_loss)

            i += 1

        if isinstance(layer, nn.MaxPool2d):
            name = "pool_" + str(i)
            model.add_module(name, layer)  # ***

    return model, style_losses, content_losses

# %%
# Optimizer (LBFGS)
def get_input_param_optimizer(input_img):
    input_param = nn.Parameter(input_img.data)
    optimizer = optim.LBFGS([input_param])
    return input_param, optimizer

# %%
import time

# %%
def train_style_transfer(cnn, content_img, style_img, input_img, num_steps=300,
                       style_weight=3500, content_weight=1):
    start_time = time.time()
    print('Starting style transfer!!')
    model, style_losses, content_losses = get_style_model_and_losses(cnn, style_img, content_img, style_weight, content_weight)
    input_param, optimizer = get_input_param_optimizer(input_img)

    ss = []
    cs = []
    
    run = [0]
    while run[0] <= num_steps:
        def steps():
            input_param.data.clamp_(0, 1)
            optimizer.zero_grad()
            model(input_param)
            style_score = 0
            content_score = 0

            for sl in style_losses:
                style_score += sl.backward()
            for cl in content_losses:
                content_score += cl.backward()

            run[0] += 1
            ss.append(style_score.item())
            cs.append(content_score.item())
            if run[0] % 50 == 0:
                print("run {}: Style Loss : {:4f} Content Loss: {:4f}".format(run, style_score.item(), content_score.item()))

            return style_score + content_score

        optimizer.step(steps)
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(elapsed_time)
    # a last correction...
    input_param.data.clamp_(0, 1)

    return input_param.data, ss, cs

# %% [markdown]
# #training loop

# %% [markdown]
# **face_sketches_path**: change to path of folder containing the content images
#
# **style_image_path**: change to path of folder containing the style images.

# %%
face_sketches_path = "/content/drive/My Drive/Group_Project/1194GoodImages"
style_images_path = "/content/drive/My Drive/Group_Project/1194AbstractImages"

# %%
sketches_list = []
style_list = []

# %%
for sketch_image in os.listdir(face_sketches_path):
  #if sketch_image.endswith(".jpg"):
  sketches_list.append(sketch_image)
  #else:
    #continue

# %%
for style_image in os.listdir(style_images_path):
  #if style_image.endswith(".jpg"):
  style_list.append(style_image)
  #else:
    #continue

# %%
len(style_list)
# Out:
# 1194

# %%
out_list = []
for i in range(1194):
  out_list.append(str(i))

# %%
out2_list = []
for i in range(1194):
  out2_list.append(str(i) + '-2')

# %% [markdown]
# **imsize** defines the output dimesion (height x width).

# %%
imsize = 256 if use_cuda else 128
transform = transforms.Compose([transforms.Resize([imsize,imsize]), transforms.ToTensor()])

# %%
for i in range(878, len(sketches_list)):
  try: 
    content_image_path = "/content/drive/My Drive/Group_Project/1194GoodImages/"
    content_image_path = content_image_path + sketches_list[i]
    style_image_path = "/content/drive/My Drive/Group_Project/1194AbstractImages/"
    style_image_path = style_image_path + style_list[i]

    content_img = image_loader(content_image_path, transform, max_size=imsize)
    style_img = image_loader(style_image_path, transform, shape=[content_img.size(2), content_img.size(3)])
    input_img = content_img.clone()

    cnn = models.vgg19(pretrained=True).features
    if use_cuda:
      cnn = cnn.cuda()

    output,ss ,cs = train_style_transfer(cnn, content_img, style_img, input_img)
    nout = output.squeeze()
    nout = nout.permute(1,2,0)

    output_path = "/content/drive/My Drive/Group_Project/output_good/" + out2_list[i] + '.jpeg'
    torchvision.utils.save_image(nout.permute(2,0,1), output_path)
  except:
    pass
# Out:
# Starting style transfer!!
# run [50]: Style Loss : 69.868942 Content Loss: 5.167918
# run [100]: Style Loss : 30.810429 Content Loss: 5.540665
# run [150]: Style Loss : 14.101691 Content Loss: 5.543618
# run [200]: Style Loss : 5.667924 Content Loss: 5.589829
# run [250]: Style Loss : 3.136970 Content Loss: 5.518428
# run [300]: Style Loss : 2.208555 Content Loss: 5.318726
# 75.50424885749817
# Starting style transfer!!
# run [50]: Style Loss : 96.535545 Content Loss: 2.989585
# run [100]: Style Loss : 12.593591 Content Loss: 3.473477
# run [150]: Style Loss : 3.416120 Content Loss: 3.475327
# run [200]: Style Loss : 2.046199 Content Loss: 3.330994
# run [250]: Style Loss : 1.467724 Content Loss: 3.213341
# run [300]: Style Loss : 1.144699 Content Loss: 3.131729
# 75.20150804519653
# Starting style transfer!!
# run [50]: Style Loss : 79.435852 Content Loss: 8.428481
# run [100]: Style Loss : 24.785551 Content Loss: 8.656047
# run [150]: Style Loss : 12.543562 Content Loss: 8.723757
# run [200]: Style Loss : 6.742910 Content Loss: 8.741575
# run [250]: Style Loss : 3.736928 Content Loss: 8.708444
# run [300]: Style Loss : 3.314535 Content Loss: 8.626943
# 75.46750378608704
# Starting style transfer!!
# run [50]: Style Loss : 88.433708 Content Loss: 2.681798
# run [100]: Style Loss : 40.492157 Content Loss: 3.070762
# run [150]: Style Loss : 25.025133 Content Loss: 3.163811
# run [200]: Style Loss : 490447.625000 Content Loss: 22.852448
# run [250]: Style Loss : 136.249329 Content Loss: 5.937190
# run [300]: Style Loss : 57.950035 Content Loss: 5.905226
# 75.53875851631165
# Starting style transfer!!
# run [50]: Style Loss : 46.408318 Content Loss: 8.066844
# run [100]: Style Loss : 11.588398 Content Loss: 7.952332
# run [150]: Style Loss : 5.723723 Content Loss: 7.731421
# run [200]: Style Loss : 3.200690 Content Loss: 7.450952
# run [250]: Style Loss : 2.651565 Content Loss: 7.139641
# run [300]: Style Loss : 1.839665 Content Loss: 6.903858
# 75.27571845054626
# Starting style transfer!!
# run [50]: Style Loss : 118.810814 Content Loss: 9.915266
# run [100]: Style Loss : 53.192543 Content Loss: 9.931681
# run [150]: Style Loss : 30.366516 Content Loss: 9.831181
# run [200]: Style Loss : 14.709814 Content Loss: 9.653345
# run [250]: Style Loss : 7.158286 Content Loss: 9.473960
# run [300]: Style Loss : 8.111844 Content Loss: 9.249012
# 75.31156969070435
# Starting style transfer!!
# run [50]: Style Loss : 21.044117 Content Loss: 1.648504
# run [100]: Style Loss : 3.355417 Content Loss: 1.680000
# run [150]: Style Loss : 2.062891 Content Loss: 1.501975
# run [200]: Style Loss : 1.503789 Content Loss: 1.452743
# run [250]: Style Loss : 1.065491 Content Loss: 1.455974
# run [300]: Style Loss : 0.785310 Content Loss: 1.458003
# 75.45896768569946
# Starting style transfer!!
# run [50]: Style Loss : 81.187241 Content Loss: 4.212757
# run [100]: Style Loss : 31.079254 Content Loss: 4.745292
# run [150]: Style Loss : 5.259847 Content Loss: 5.042294
# run [200]: Style Loss : 1.049953 Content Loss: 5.002145
# run [250]: Style Loss : 0.648036 Content Loss: 4.566672
# run [300]: Style Loss : 0.513313 Content Loss: 4.295839
# 75.11158180236816
# Starting style transfer!!
# run [50]: Style Loss : 9.111018 Content Loss: 1.650285
# run [100]: Style Loss : 2.842731 Content Loss: 1.867245
# run [150]: Style Loss : 1.279341 Content Loss: 1.874649
# run [200]: Style Loss : 0.893520 Content Loss: 1.828876
# run [250]: Style Loss : 0.731719 Content Loss: 1.786311
# run [300]: Style Loss : 0.626775 Content Loss: 1.762250
# 75.06990027427673
# Starting style transfer!!
# run [50]: Style Loss : 26.019104 Content Loss: 5.093170
# run [100]: Style Loss : 9.011356 Content Loss: 5.351181
# run [150]: Style Loss : 3.502482 Content Loss: 5.393050
# run [200]: Style Loss : 1.528972 Content Loss: 5.354133
# run [250]: Style Loss : 1.028125 Content Loss: 5.245921
# run [300]: Style Loss : 0.816911 Content Loss: 5.122613
# 75.34158444404602
# Starting style transfer!!
# run [50]: Style Loss : 214.076172 Content Loss: 4.752422
# run [100]: Style Loss : 31.874336 Content Loss: 5.246021
# run [150]: Style Loss : 12.529730 Content Loss: 4.974711
# run [200]: Style Loss : 4.182961 Content Loss: 4.712196
# run [250]: Style Loss : 1.104700 Content Loss: 4.530749
# run [300]: Style Loss : 0.640968 Content Loss: 4.252951
# 75.15703392028809
# Starting style transfer!!
# run [50]: Style Loss : 105.509392 Content Loss: 7.510825
# run [100]: Style Loss : 42.212811 Content Loss: 7.919864
# run [150]: Style Loss : 20.890120 Content Loss: 8.099628
# run [200]: Style Loss : 10.901960 Content Loss: 8.174950
# run [250]: Style Loss : 4.343546 Content Loss: 8.253001
# run [300]: Style Loss : 2.261774 Content Loss: 8.262031
# 75.04357314109802
# Starting style transfer!!
# run [50]: Style Loss : 114.996338 Content Loss: 5.934566
# run [100]: Style Loss : 41.057610 Content Loss: 6.446942
# run [150]: Style Loss : 20.131166 Content Loss: 6.656688
# run [200]: Style Loss : 10.001146 Content Loss: 6.719023
# run [250]: Style Loss : 4.129952 Content Loss: 6.774712
# run [300]: Style Loss : 1.923753 Content Loss: 6.747066
# 75.36248326301575
# Starting style transfer!!
# run [50]: Style Loss : 101.170265 Content Loss: 2.797621
# run [100]: Style Loss : 39.178040 Content Loss: 2.979129
# run [150]: Style Loss : 9.678879 Content Loss: 3.061450
# run [200]: Style Loss : 2.009847 Content Loss: 3.033771
# run [250]: Style Loss : 1.291757 Content Loss: 2.804660
# run [300]: Style Loss : 0.996252 Content Loss: 2.681029
# 75.4642493724823
# Starting style transfer!!
# run [50]: Style Loss : 140.971100 Content Loss: 15.354660
# run [100]: Style Loss : 31.404745 Content Loss: 15.427836
# run [150]: Style Loss : 13.403819 Content Loss: 15.387304
# run [200]: Style Loss : 7.543779 Content Loss: 15.245691
# run [250]: Style Loss : 4.612505 Content Loss: 15.016942
# run [300]: Style Loss : 3.076584 Content Loss: 14.811481
# 75.34382104873657
# Starting style transfer!!
# run [50]: Style Loss : 42.666435 Content Loss: 2.890339
# run [100]: Style Loss : 19.795362 Content Loss: 3.338833
# run [150]: Style Loss : 6.390887 Content Loss: 3.632888
# run [200]: Style Loss : 3.741162 Content Loss: 3.636951
# run [250]: Style Loss : 3.012209 Content Loss: 3.477365
# run [300]: Style Loss : 2.585371 Content Loss: 3.354478
# 74.91365098953247
# Starting style transfer!!
# run [50]: Style Loss : 20.284071 Content Loss: 4.437975
# run [100]: Style Loss : 7.140091 Content Loss: 4.689221
# run [150]: Style Loss : 2.865067 Content Loss: 4.805559
# run [200]: Style Loss : 1.286977 Content Loss: 4.784938
# run [250]: Style Loss : 0.866612 Content Loss: 4.691638
# run [300]: Style Loss : 0.687880 Content Loss: 4.575763
# 75.17330479621887
# Starting style transfer!!
# run [50]: Style Loss : 94.766701 Content Loss: 4.244802
# run [100]: Style Loss : 31.037237 Content Loss: 4.841045
# run [150]: Style Loss : 3.700034 Content Loss: 5.248574
# run [200]: Style Loss : 0.845626 Content Loss: 5.049023
# run [250]: Style Loss : 0.510188 Content Loss: 4.622330
# run [300]: Style Loss : 0.419554 Content Loss: 4.335361
# 75.6857557296753
# Starting style transfer!!
# run [50]: Style Loss : 2.610827 Content Loss: 1.272763
# run [100]: Style Loss : 1.106718 Content Loss: 1.228093
# run [150]: Style Loss : 0.631223 Content Loss: 1.194062
# run [200]: Style Loss : 0.451213 Content Loss: 1.155406
# run [250]: Style Loss : 0.386141 Content Loss: 1.123192
# run [300]: Style Loss : 0.361388 Content Loss: 1.106653
# 75.22988080978394
# Starting style transfer!!
# run [50]: Style Loss : 89.533554 Content Loss: 6.609379
# run [100]: Style Loss : 24.510885 Content Loss: 6.982946
# run [150]: Style Loss : 10.877408 Content Loss: 7.158382
# run [200]: Style Loss : 5.974552 Content Loss: 7.250637
# run [250]: Style Loss : 3.520650 Content Loss: 7.277268
# run [300]: Style Loss : 2.495177 Content Loss: 7.271031
# 75.49363136291504
# Starting style transfer!!
# run [50]: Style Loss : 213.764816 Content Loss: 13.062620
# run [100]: Style Loss : 50.481781 Content Loss: 13.507734
# run [150]: Style Loss : 24.020767 Content Loss: 13.656414
# run [200]: Style Loss : 14.535612 Content Loss: 13.724377
# run [250]: Style Loss : 10.853350 Content Loss: 13.746646
# run [300]: Style Loss : 7.140773 Content Loss: 13.727839
# 75.46153974533081
# Starting style transfer!!
# run [50]: Style Loss : 38.020958 Content Loss: 5.430594
# run [100]: Style Loss : 11.153896 Content Loss: 5.754024
# run [150]: Style Loss : 4.350384 Content Loss: 5.783772
# run [200]: Style Loss : 1.687829 Content Loss: 5.706088
# run [250]: Style Loss : 1.067388 Content Loss: 5.525223
# run [300]: Style Loss : 0.864193 Content Loss: 5.332500
# 75.05195879936218
# Starting style transfer!!
# run [50]: Style Loss : 47.950073 Content Loss: 4.936941
# run [100]: Style Loss : 11.175687 Content Loss: 5.200534
# run [150]: Style Loss : 4.330054 Content Loss: 5.211507
# run [200]: Style Loss : 2.320659 Content Loss: 5.134116
# run [250]: Style Loss : 1.491214 Content Loss: 5.071605
# run [300]: Style Loss : 1.186787 Content Loss: 4.997911
# 74.79758858680725
# Starting style transfer!!
# run [50]: Style Loss : 232.811096 Content Loss: 4.467707
# run [100]: Style Loss : 74.559021 Content Loss: 4.979888
# run [150]: Style Loss : 35.425144 Content Loss: 5.041861
# run [200]: Style Loss : 8.856618 Content Loss: 5.239244
# run [250]: Style Loss : 2.130822 Content Loss: 5.207967
# run [300]: Style Loss : 1.108525 Content Loss: 4.986954
# 74.92753291130066
# Starting style transfer!!
# run [50]: Style Loss : 18.046562 Content Loss: 3.435506
# run [100]: Style Loss : 4.505872 Content Loss: 3.728648
# run [150]: Style Loss : 1.896399 Content Loss: 3.664331
# run [200]: Style Loss : 0.895100 Content Loss: 3.591244
# run [250]: Style Loss : 0.689474 Content Loss: 3.465426
# run [300]: Style Loss : 0.596255 Content Loss: 3.377370
# 75.07915735244751
# Starting style transfer!!
# run [50]: Style Loss : 17.139154 Content Loss: 2.766538
# run [100]: Style Loss : 4.713670 Content Loss: 2.996169
# run [150]: Style Loss : 1.556241 Content Loss: 2.974073
# run [200]: Style Loss : 1.012539 Content Loss: 2.784991
# run [250]: Style Loss : 0.781054 Content Loss: 2.658997
# run [300]: Style Loss : 0.626510 Content Loss: 2.574626
# 75.08378553390503
# Starting style transfer!!
# run [50]: Style Loss : 64.479385 Content Loss: 4.468446
# run [100]: Style Loss : 16.265413 Content Loss: 4.760559
# run [150]: Style Loss : 6.892422 Content Loss: 4.915142
# run [200]: Style Loss : 3.716383 Content Loss: 4.965330
# run [250]: Style Loss : 2.320545 Content Loss: 4.975729
# run [300]: Style Loss : 1.908106 Content Loss: 4.952217
# 74.62237000465393
# Starting style transfer!!
# run [50]: Style Loss : 216.688034 Content Loss: 3.337361
# run [100]: Style Loss : 110.508469 Content Loss: 4.085774
# run [150]: Style Loss : 22.695704 Content Loss: 4.595373
# run [200]: Style Loss : 1.770733 Content Loss: 4.494481
# run [250]: Style Loss : 0.547144 Content Loss: 3.934076
# run [300]: Style Loss : 0.348040 Content Loss: 3.494312
# 74.72669959068298
# Starting style transfer!!
# run [50]: Style Loss : 49.107258 Content Loss: 5.655816
# run [100]: Style Loss : 12.939396 Content Loss: 5.984639
# run [150]: Style Loss : 5.991628 Content Loss: 6.100973
# run [200]: Style Loss : 4.549002 Content Loss: 6.170181
# run [250]: Style Loss : 1.902101 Content Loss: 6.144672
# run [300]: Style Loss : 1.255651 Content Loss: 6.103040
# 74.83455038070679
# Starting style transfer!!
# run [50]: Style Loss : 115.111389 Content Loss: 9.694161
# run [100]: Style Loss : 30.655029 Content Loss: 10.153814
# run [150]: Style Loss : 13.123240 Content Loss: 10.372229
# run [200]: Style Loss : 7.347649 Content Loss: 10.408020
# run [250]: Style Loss : 4.564300 Content Loss: 10.386915
# run [300]: Style Loss : 3.286903 Content Loss: 10.361022
# 74.7605197429657
# Starting style transfer!!
# run [50]: Style Loss : 107.392067 Content Loss: 4.118054
# run [100]: Style Loss : 48.435654 Content Loss: 4.739069
# run [150]: Style Loss : 15.670179 Content Loss: 5.113378
# run [200]: Style Loss : 3.159574 Content Loss: 5.335929
# run [250]: Style Loss : 1.753235 Content Loss: 5.041769
# run [300]: Style Loss : 1.212380 Content Loss: 4.646626
# 74.57256746292114
# Starting style transfer!!
# run [50]: Style Loss : 189.473358 Content Loss: 11.275345
# run [100]: Style Loss : 47.959793 Content Loss: 11.757523
# run [150]: Style Loss : 20.571629 Content Loss: 11.950293
# run [200]: Style Loss : 10.765687 Content Loss: 12.062130
# run [250]: Style Loss : 6.155624 Content Loss: 12.086080
# run [300]: Style Loss : 3.620580 Content Loss: 12.079401
# 74.74000668525696
# Starting style transfer!!
# run [50]: Style Loss : 191.475327 Content Loss: 7.996372
# run [100]: Style Loss : 72.312317 Content Loss: 8.591463
# run [150]: Style Loss : 15.779202 Content Loss: 8.628172
# run [200]: Style Loss : 6.760044 Content Loss: 8.496737
# run [250]: Style Loss : 2.441119 Content Loss: 8.394065
# run [300]: Style Loss : 1.125492 Content Loss: 8.263077
# 74.68544936180115
# Starting style transfer!!
# run [50]: Style Loss : 64.108063 Content Loss: 8.099470
# run [100]: Style Loss : 27.024036 Content Loss: 8.395695
# run [150]: Style Loss : 9.166351 Content Loss: 8.643883
# run [200]: Style Loss : 2.319455 Content Loss: 8.775164
# run [250]: Style Loss : 0.963383 Content Loss: 8.674964
# run [300]: Style Loss : 0.646860 Content Loss: 8.353144
# 74.58789086341858
# Starting style transfer!!
# run [50]: Style Loss : 221.366119 Content Loss: 3.692518
# run [100]: Style Loss : 31.728687 Content Loss: 4.075769
# run [150]: Style Loss : 15.042259 Content Loss: 4.009849
# run [200]: Style Loss : 4.372067 Content Loss: 3.948906
# run [250]: Style Loss : 1.265314 Content Loss: 3.843263
# run [300]: Style Loss : 0.782127 Content Loss: 3.655601
# 74.7639992237091
# Starting style transfer!!
# run [50]: Style Loss : 113.916870 Content Loss: 6.855452
# run [100]: Style Loss : 46.754585 Content Loss: 6.959023
# run [150]: Style Loss : 21.989672 Content Loss: 6.824669
# run [200]: Style Loss : 4.181418 Content Loss: 6.740052
# run [250]: Style Loss : 1.029242 Content Loss: 6.547723
# run [300]: Style Loss : 0.633927 Content Loss: 6.110787
# 74.59648990631104
# Starting style transfer!!
# run [50]: Style Loss : 50.246788 Content Loss: 9.258143
# run [100]: Style Loss : 16.499178 Content Loss: 9.574915
# run [150]: Style Loss : 6.382488 Content Loss: 9.592695
# run [200]: Style Loss : 2.435799 Content Loss: 9.522543
# run [250]: Style Loss : 1.192342 Content Loss: 9.384875
# run [300]: Style Loss : 0.860476 Content Loss: 9.152952
# 74.6976363658905
# Starting style transfer!!
# run [50]: Style Loss : 3.373125 Content Loss: 2.349000
# run [100]: Style Loss : 1.152275 Content Loss: 2.387887
# run [150]: Style Loss : 0.672327 Content Loss: 2.325256
# run [200]: Style Loss : 0.488881 Content Loss: 2.259834
# run [250]: Style Loss : 0.396745 Content Loss: 2.204005
# run [300]: Style Loss : 0.339648 Content Loss: 2.161151
# 74.40681433677673
# Starting style transfer!!
# run [50]: Style Loss : 26.194849 Content Loss: 6.057966
# run [100]: Style Loss : 6.124400 Content Loss: 5.936964
# run [150]: Style Loss : 2.982538 Content Loss: 5.682362
# run [200]: Style Loss : 1.931132 Content Loss: 5.419550
# run [250]: Style Loss : 1.420607 Content Loss: 5.159974
# run [300]: Style Loss : 1.167022 Content Loss: 4.892015
# 74.74421501159668
# Starting style transfer!!
# run [50]: Style Loss : 66.471016 Content Loss: 8.462558
# run [100]: Style Loss : 19.792467 Content Loss: 8.313787
# run [150]: Style Loss : 9.155716 Content Loss: 7.961318
# run [200]: Style Loss : 3.319987 Content Loss: 7.663906
# run [250]: Style Loss : 1.373159 Content Loss: 7.475553
# run [300]: Style Loss : 0.990337 Content Loss: 7.148864
# 74.6365704536438
# Starting style transfer!!
# run [50]: Style Loss : 109.938614 Content Loss: 3.301696
# run [100]: Style Loss : 32.949978 Content Loss: 3.757437
# run [150]: Style Loss : 15.703859 Content Loss: 3.831969
# run [200]: Style Loss : 10.222980 Content Loss: 3.865159
# run [250]: Style Loss : 7.377474 Content Loss: 3.883512
# run [300]: Style Loss : 5.822044 Content Loss: 3.879311
# 74.66770076751709
# Starting style transfer!!
# run [50]: Style Loss : 47.111938 Content Loss: 6.231799
# run [100]: Style Loss : 18.491343 Content Loss: 6.620167
# run [150]: Style Loss : 8.594183 Content Loss: 6.724656
# run [200]: Style Loss : 3.210537 Content Loss: 6.784981
# run [250]: Style Loss : 1.782226 Content Loss: 6.740594
# run [300]: Style Loss : 1.307214 Content Loss: 6.572186
# 74.79265832901001
# Starting style transfer!!
# run [50]: Style Loss : 141.437363 Content Loss: 3.925518
# run [100]: Style Loss : 62.554100 Content Loss: 4.225987
# run [150]: Style Loss : 20.007572 Content Loss: 4.698052
# run [200]: Style Loss : 4.987750 Content Loss: 5.020693
# run [250]: Style Loss : 2.600941 Content Loss: 4.908422
# run [300]: Style Loss : 1.888118 Content Loss: 4.636439
# 74.68625593185425
# Starting style transfer!!
# run [50]: Style Loss : 226.633865 Content Loss: 13.543776
# run [100]: Style Loss : 32.084763 Content Loss: 14.157833
# run [150]: Style Loss : 15.569680 Content Loss: 14.269614
# run [200]: Style Loss : 8.616776 Content Loss: 14.279034
# run [250]: Style Loss : 4.512580 Content Loss: 14.211606
# run [300]: Style Loss : 2.687250 Content Loss: 14.154304
# 74.6225094795227
# Starting style transfer!!
# run [50]: Style Loss : 46.621101 Content Loss: 5.567755
# run [100]: Style Loss : 15.758446 Content Loss: 6.003301
# run [150]: Style Loss : 7.423135 Content Loss: 6.165737
# run [200]: Style Loss : 4.445620 Content Loss: 6.181367
# run [250]: Style Loss : 3.302713 Content Loss: 6.149761
# run [300]: Style Loss : 2.694803 Content Loss: 6.083455
# 74.81629610061646
# Starting style transfer!!
# run [50]: Style Loss : 23.230015 Content Loss: 2.348333
# run [100]: Style Loss : 10.551391 Content Loss: 2.866173
# run [150]: Style Loss : 6.283441 Content Loss: 3.108114
# run [200]: Style Loss : 3.747861 Content Loss: 3.387915
# run [250]: Style Loss : 2.232358 Content Loss: 3.436769
# run [300]: Style Loss : 1.465264 Content Loss: 3.294441
# 74.77929186820984
# Starting style transfer!!
# run [50]: Style Loss : 71.480843 Content Loss: 7.064470
# run [100]: Style Loss : 32.035854 Content Loss: 7.412934
# run [150]: Style Loss : 10.575052 Content Loss: 7.702791
# run [200]: Style Loss : 3.019936 Content Loss: 7.880114
# run [250]: Style Loss : 1.612425 Content Loss: 7.722214
# run [300]: Style Loss : 1.155997 Content Loss: 7.415945
# 74.85397410392761
# Starting style transfer!!
# run [50]: Style Loss : 20.415998 Content Loss: 3.469196
# run [100]: Style Loss : 5.100068 Content Loss: 3.684310
# run [150]: Style Loss : 2.392337 Content Loss: 3.635520
# run [200]: Style Loss : 1.393690 Content Loss: 3.576087
# run [250]: Style Loss : 1.035840 Content Loss: 3.482664
# run [300]: Style Loss : 0.859893 Content Loss: 3.401264
# 74.68529438972473
# Starting style transfer!!
# run [50]: Style Loss : 10.071481 Content Loss: 1.732690
# run [100]: Style Loss : 4.011612 Content Loss: 1.977791
# run [150]: Style Loss : 2.273325 Content Loss: 2.067361
# run [200]: Style Loss : 4.143584 Content Loss: 2.096676
# run [250]: Style Loss : 1.436460 Content Loss: 2.157697
# run [300]: Style Loss : 1.661015 Content Loss: 2.286674
# 74.7593150138855
# Starting style transfer!!
# run [50]: Style Loss : 29.725622 Content Loss: 5.789250
# run [100]: Style Loss : 9.930712 Content Loss: 5.845399
# run [150]: Style Loss : 2.342156 Content Loss: 5.820959
# run [200]: Style Loss : 1.032294 Content Loss: 5.682171
# run [250]: Style Loss : 0.741864 Content Loss: 5.450791
# run [300]: Style Loss : 0.618592 Content Loss: 5.265708
# 74.72619581222534
# Starting style transfer!!
# run [50]: Style Loss : 5.127987 Content Loss: 1.757680
# run [100]: Style Loss : 1.315942 Content Loss: 1.688233
# run [150]: Style Loss : 0.509202 Content Loss: 1.577282
# run [200]: Style Loss : 0.381810 Content Loss: 1.462885
# run [250]: Style Loss : 0.332497 Content Loss: 1.412226
# run [300]: Style Loss : 0.280265 Content Loss: 1.387834
# 74.50700783729553
# Starting style transfer!!
# run [50]: Style Loss : 7.389610 Content Loss: 1.899204
# run [100]: Style Loss : 2.622630 Content Loss: 1.847189
# run [150]: Style Loss : 1.300451 Content Loss: 1.802826
# run [200]: Style Loss : 0.833390 Content Loss: 1.729865
# run [250]: Style Loss : 0.662606 Content Loss: 1.681643
# run [300]: Style Loss : 0.563558 Content Loss: 1.650370
# 74.54866218566895
# Starting style transfer!!
# run [50]: Style Loss : 153.505798 Content Loss: 9.678883
# run [100]: Style Loss : 69.741547 Content Loss: 9.924902
# run [150]: Style Loss : 40.896305 Content Loss: 10.034710
# run [200]: Style Loss : 22.382206 Content Loss: 10.143997
# run [250]: Style Loss : 10.843044 Content Loss: 10.209195
# run [300]: Style Loss : 6.914887 Content Loss: 10.215268
# 74.78163361549377
# Starting style transfer!!
# run [50]: Style Loss : 155.022430 Content Loss: 4.040036
# run [100]: Style Loss : 70.444748 Content Loss: 4.597232
# run [150]: Style Loss : 31.436768 Content Loss: 4.881254
# run [200]: Style Loss : 7.504514 Content Loss: 5.175490
# run [250]: Style Loss : 2.648262 Content Loss: 5.189943
# run [300]: Style Loss : 1.653549 Content Loss: 4.828479
# 74.58690977096558
# Starting style transfer!!
# run [50]: Style Loss : 12.378103 Content Loss: 1.838462
# run [100]: Style Loss : 4.455916 Content Loss: 2.047866
# run [150]: Style Loss : 1.580212 Content Loss: 2.051164
# run [200]: Style Loss : 0.854037 Content Loss: 1.937964
# run [250]: Style Loss : 0.696112 Content Loss: 1.835279
# run [300]: Style Loss : 0.583450 Content Loss: 1.772921
# 74.63714671134949
# Starting style transfer!!
# run [50]: Style Loss : 10.599456 Content Loss: 2.652182
# run [100]: Style Loss : 2.982862 Content Loss: 2.824708
# run [150]: Style Loss : 1.140973 Content Loss: 2.801136
# run [200]: Style Loss : 0.715930 Content Loss: 2.701624
# run [250]: Style Loss : 0.580983 Content Loss: 2.607668
# run [300]: Style Loss : 0.498924 Content Loss: 2.544757
# 74.54255390167236
# Starting style transfer!!
# run [50]: Style Loss : 158.633881 Content Loss: 3.645965
# run [100]: Style Loss : 61.977844 Content Loss: 4.135292
# run [150]: Style Loss : 17.511093 Content Loss: 4.456353
# run [200]: Style Loss : 4.599798 Content Loss: 4.727139
# run [250]: Style Loss : 1.947503 Content Loss: 4.335543
# run [300]: Style Loss : 0.927757 Content Loss: 3.819615
# 74.60361838340759
# Starting style transfer!!
# run [50]: Style Loss : 94.517021 Content Loss: 5.330940
# run [100]: Style Loss : 28.652092 Content Loss: 5.760766
# run [150]: Style Loss : 12.306839 Content Loss: 5.973080
# run [200]: Style Loss : 6.144062 Content Loss: 6.107849
# run [250]: Style Loss : 3.507178 Content Loss: 6.173204
# run [300]: Style Loss : 2.416153 Content Loss: 6.178357
# 74.3874785900116
# Starting style transfer!!
# run [50]: Style Loss : 63.502804 Content Loss: 8.406008
# run [100]: Style Loss : 17.273790 Content Loss: 8.314508
# run [150]: Style Loss : 7.919262 Content Loss: 8.091210
# run [200]: Style Loss : 4.547674 Content Loss: 7.822887
# run [250]: Style Loss : 3.029440 Content Loss: 7.521301
# run [300]: Style Loss : 2.412722 Content Loss: 7.244227
# 74.63866019248962
# Starting style transfer!!
# run [50]: Style Loss : 94.309677 Content Loss: 12.378050
# run [100]: Style Loss : 18.587029 Content Loss: 12.419632
# run [150]: Style Loss : 6.727308 Content Loss: 12.291603
# run [200]: Style Loss : 3.578808 Content Loss: 12.032319
# run [250]: Style Loss : 2.049170 Content Loss: 11.677061
# run [300]: Style Loss : 1.255024 Content Loss: 11.353476
# 74.67548036575317
# Starting style transfer!!
# run [50]: Style Loss : 57.560177 Content Loss: 3.532210
# run [100]: Style Loss : 12.743351 Content Loss: 4.034387
# run [150]: Style Loss : 4.918494 Content Loss: 4.141387
# run [200]: Style Loss : 2.739186 Content Loss: 4.134395
# run [250]: Style Loss : 1.892161 Content Loss: 4.097762
# run [300]: Style Loss : 1.523935 Content Loss: 4.019937
# 74.70161581039429
# Starting style transfer!!
# run [50]: Style Loss : 158.532974 Content Loss: 6.863064
# run [100]: Style Loss : 88.444901 Content Loss: 7.667210
# run [150]: Style Loss : 28.991352 Content Loss: 7.704283
# run [200]: Style Loss : 15.580124 Content Loss: 7.750127
# run [250]: Style Loss : 6.424255 Content Loss: 7.808034
# run [300]: Style Loss : 2.618897 Content Loss: 7.820964
# 74.58622622489929
# Starting style transfer!!
# run [50]: Style Loss : 162.664093 Content Loss: 6.331513
# run [100]: Style Loss : 91.354218 Content Loss: 6.559666
# run [150]: Style Loss : 62.551003 Content Loss: 6.623433
# run [200]: Style Loss : 40.124825 Content Loss: 6.696863
# run [250]: Style Loss : 27.792557 Content Loss: 6.718537
# run [300]: Style Loss : 19.998957 Content Loss: 6.749261
# 74.5646984577179
# Starting style transfer!!
# run [50]: Style Loss : 98.198563 Content Loss: 5.446921
# run [100]: Style Loss : 37.265011 Content Loss: 5.859465
# run [150]: Style Loss : 18.541084 Content Loss: 6.037199
# run [200]: Style Loss : 11.061085 Content Loss: 6.131912
# run [250]: Style Loss : 6.841323 Content Loss: 6.182505
# run [300]: Style Loss : 4.901340 Content Loss: 6.210876
# 74.5031909942627
# Starting style transfer!!
# run [50]: Style Loss : 239.303741 Content Loss: 3.406706
# run [100]: Style Loss : 109.079025 Content Loss: 4.075682
# run [150]: Style Loss : 38.180946 Content Loss: 4.413084
# run [200]: Style Loss : 9.428380 Content Loss: 4.486442
# run [250]: Style Loss : 7.143442 Content Loss: 4.404621
# run [300]: Style Loss : 0.733145 Content Loss: 4.116344
# 74.43074536323547
# Starting style transfer!!
# run [50]: Style Loss : 35.030834 Content Loss: 2.526999
# run [100]: Style Loss : 12.963440 Content Loss: 2.921045
# run [150]: Style Loss : 4.194991 Content Loss: 3.014566
# run [200]: Style Loss : 1.636577 Content Loss: 2.983044
# run [250]: Style Loss : 1.144575 Content Loss: 2.880143
# run [300]: Style Loss : 0.915209 Content Loss: 2.806395
# 74.70310306549072
# Starting style transfer!!
# run [50]: Style Loss : 45.440937 Content Loss: 11.489207
# run [100]: Style Loss : 10.337111 Content Loss: 11.380568
# run [150]: Style Loss : 4.879995 Content Loss: 11.096732
# run [200]: Style Loss : 2.494809 Content Loss: 10.704533
# run [250]: Style Loss : 1.453917 Content Loss: 10.341638
# run [300]: Style Loss : 1.157945 Content Loss: 9.984108
# 74.6202244758606
# Starting style transfer!!
# run [50]: Style Loss : 122.486824 Content Loss: 8.142278
# run [100]: Style Loss : 47.143730 Content Loss: 8.508890
# run [150]: Style Loss : 22.102276 Content Loss: 8.698162
# run [200]: Style Loss : 8.101225 Content Loss: 8.794939
# run [250]: Style Loss : 3.102336 Content Loss: 8.852770
# run [300]: Style Loss : 1.844179 Content Loss: 8.788715
# 74.54054689407349
# Starting style transfer!!
# run [50]: Style Loss : 35.932106 Content Loss: 4.383538
# run [100]: Style Loss : 11.960425 Content Loss: 4.680310
# run [150]: Style Loss : 5.507385 Content Loss: 4.759348
# run [200]: Style Loss : 2.742018 Content Loss: 4.767133
# run [250]: Style Loss : 1.791789 Content Loss: 4.702445
# run [300]: Style Loss : 1.418723 Content Loss: 4.604609
# 74.3929762840271
# Starting style transfer!!
# run [50]: Style Loss : 565.764282 Content Loss: 7.495491
# run [100]: Style Loss : 47.739002 Content Loss: 8.260756
# run [150]: Style Loss : 15.833861 Content Loss: 8.364009
# run [200]: Style Loss : 8.414589 Content Loss: 8.418707
# run [250]: Style Loss : 5.190110 Content Loss: 8.460993
# run [300]: Style Loss : 3.621887 Content Loss: 8.484596
# 74.58429861068726
# Starting style transfer!!
# run [50]: Style Loss : 10.596504 Content Loss: 1.781642
# run [100]: Style Loss : 3.550735 Content Loss: 2.036920
# run [150]: Style Loss : 1.882004 Content Loss: 2.140322
# run [200]: Style Loss : 1.309014 Content Loss: 2.179726
# run [250]: Style Loss : 1.033368 Content Loss: 2.169832
# run [300]: Style Loss : 0.955297 Content Loss: 2.145917
# 74.67119646072388
# Starting style transfer!!
# run [50]: Style Loss : 115.948898 Content Loss: 3.108127
# run [100]: Style Loss : 45.807873 Content Loss: 3.156220
# run [150]: Style Loss : 7.270854 Content Loss: 3.411227
# run [200]: Style Loss : 1.402213 Content Loss: 3.229629
# run [250]: Style Loss : 0.857580 Content Loss: 2.910189
# run [300]: Style Loss : 0.660767 Content Loss: 2.715305
# 74.33121824264526
# Starting style transfer!!
# run [50]: Style Loss : 38.206116 Content Loss: 4.951000
# run [100]: Style Loss : 12.830660 Content Loss: 5.207311
# run [150]: Style Loss : 5.943167 Content Loss: 5.275855
# run [200]: Style Loss : 3.304664 Content Loss: 5.282677
# run [250]: Style Loss : 2.280145 Content Loss: 5.259749
# run [300]: Style Loss : 1.842595 Content Loss: 5.204498
# 74.63360524177551
# Starting style transfer!!
# run [50]: Style Loss : 92.506874 Content Loss: 7.933150
# run [100]: Style Loss : 25.194422 Content Loss: 8.390435
# run [150]: Style Loss : 12.475898 Content Loss: 8.503809
# run [200]: Style Loss : 6.400884 Content Loss: 8.561381
# run [250]: Style Loss : 3.675651 Content Loss: 8.553770
# run [300]: Style Loss : 2.550105 Content Loss: 8.489418
# 74.47935652732849
# Starting style transfer!!
# run [50]: Style Loss : 67.891739 Content Loss: 3.705488
# run [100]: Style Loss : 26.265114 Content Loss: 4.102943
# run [150]: Style Loss : 5.273098 Content Loss: 4.391797
# run [200]: Style Loss : 2.344107 Content Loss: 4.263584
# run [250]: Style Loss : 1.849116 Content Loss: 3.890083
# run [300]: Style Loss : 1.566938 Content Loss: 3.686868
# 74.85093212127686
# Starting style transfer!!
# run [50]: Style Loss : 122.668076 Content Loss: 11.284112
# run [100]: Style Loss : 29.013298 Content Loss: 11.380651
# run [150]: Style Loss : 12.941574 Content Loss: 11.304836
# run [200]: Style Loss : 7.576444 Content Loss: 11.165737
# run [250]: Style Loss : 4.228383 Content Loss: 10.923914
# run [300]: Style Loss : 2.304024 Content Loss: 10.652061
# 74.7243263721466
# Starting style transfer!!
# run [50]: Style Loss : 155.927658 Content Loss: 5.851759
# run [100]: Style Loss : 77.878471 Content Loss: 6.401378
# run [150]: Style Loss : 28.602468 Content Loss: 6.732642
# run [200]: Style Loss : 5.595766 Content Loss: 6.956114
# run [250]: Style Loss : 1.853797 Content Loss: 6.905282
# run [300]: Style Loss : 1.125833 Content Loss: 6.465635
# 74.65845918655396
# Starting style transfer!!
# run [50]: Style Loss : 229.699768 Content Loss: 7.091919
# run [100]: Style Loss : 70.176247 Content Loss: 7.264984
# run [150]: Style Loss : 37.588314 Content Loss: 7.166499
# run [200]: Style Loss : 12.001084 Content Loss: 7.157899
# run [250]: Style Loss : 3.117283 Content Loss: 7.198246
# run [300]: Style Loss : 1.014801 Content Loss: 7.071158
# 74.28748536109924
# Starting style transfer!!
# run [50]: Style Loss : 48.681793 Content Loss: 3.211581
# run [100]: Style Loss : 11.195049 Content Loss: 3.686810
# run [150]: Style Loss : 5.165491 Content Loss: 3.800066
# run [200]: Style Loss : 2.934422 Content Loss: 3.879122
# run [250]: Style Loss : 2.097428 Content Loss: 3.903550
# run [300]: Style Loss : 1.666427 Content Loss: 3.878435
# 74.61364889144897
# Starting style transfer!!
# run [50]: Style Loss : 62.933338 Content Loss: 6.936237
# run [100]: Style Loss : 17.422634 Content Loss: 7.433434
# run [150]: Style Loss : 7.165082 Content Loss: 7.590225
# run [200]: Style Loss : 3.405038 Content Loss: 7.593806
# run [250]: Style Loss : 2.044842 Content Loss: 7.545194
# run [300]: Style Loss : 1.486899 Content Loss: 7.452485
# 74.85048747062683
# Starting style transfer!!
# run [50]: Style Loss : 49.578434 Content Loss: 9.674303
# run [100]: Style Loss : 15.499877 Content Loss: 9.561142
# run [150]: Style Loss : 7.369916 Content Loss: 9.314358
# run [200]: Style Loss : 3.888010 Content Loss: 9.077461
# run [250]: Style Loss : 2.645798 Content Loss: 8.835749
# run [300]: Style Loss : 2.054060 Content Loss: 8.610308
# 74.51422429084778
# Starting style transfer!!
# run [50]: Style Loss : 71.443344 Content Loss: 7.513239
# run [100]: Style Loss : 15.985507 Content Loss: 7.735308
# run [150]: Style Loss : 7.630040 Content Loss: 7.839372
# run [200]: Style Loss : 5.638772 Content Loss: 7.856597
# run [250]: Style Loss : 3.395970 Content Loss: 7.888830
# run [300]: Style Loss : 31780.384766 Content Loss: 10.128035
# 74.42435812950134
# Starting style transfer!!
# run [50]: Style Loss : 105.318108 Content Loss: 4.694877
# run [100]: Style Loss : 41.716614 Content Loss: 5.232316
# run [150]: Style Loss : 7.130702 Content Loss: 5.671771
# run [200]: Style Loss : 1.943833 Content Loss: 5.659149
# run [250]: Style Loss : 1.161068 Content Loss: 5.302686
# run [300]: Style Loss : 0.866093 Content Loss: 5.046223
# 74.625967502594
# Starting style transfer!!
# run [50]: Style Loss : 38.180462 Content Loss: 3.274502
# run [100]: Style Loss : 10.723551 Content Loss: 3.618212
# run [150]: Style Loss : 5.085562 Content Loss: 3.673687
# run [200]: Style Loss : 2.832814 Content Loss: 3.688445
# run [250]: Style Loss : 1.962263 Content Loss: 3.636586
# run [300]: Style Loss : 1.520638 Content Loss: 3.579463
# 74.50790190696716
# Starting style transfer!!
# run [50]: Style Loss : 80.340218 Content Loss: 5.207130
# run [100]: Style Loss : 35.980659 Content Loss: 5.597406
# run [150]: Style Loss : 19.867554 Content Loss: 5.836934
# run [200]: Style Loss : 11.169522 Content Loss: 5.992526
# run [250]: Style Loss : 6.998739 Content Loss: 6.060378
# run [300]: Style Loss : 5.361602 Content Loss: 6.063847
# 74.4372501373291
# Starting style transfer!!
# run [50]: Style Loss : 193.539536 Content Loss: 9.758096
# run [100]: Style Loss : 54.829853 Content Loss: 10.550167
# run [150]: Style Loss : 28.715780 Content Loss: 10.638720
# run [200]: Style Loss : 14.011353 Content Loss: 10.686699
# run [250]: Style Loss : 5.546682 Content Loss: 10.642681
# run [300]: Style Loss : 2.168490 Content Loss: 10.551805
# 74.5967903137207
# Starting style transfer!!
# run [50]: Style Loss : 301.568146 Content Loss: 7.742680
# run [100]: Style Loss : 74.064270 Content Loss: 8.341038
# run [150]: Style Loss : 37.157116 Content Loss: 8.475312
# run [200]: Style Loss : 22.941990 Content Loss: 8.490232
# run [250]: Style Loss : 10.934563 Content Loss: 8.571690
# run [300]: Style Loss : 4.173453 Content Loss: 8.544498
# 74.57310199737549
# Starting style transfer!!
# run [50]: Style Loss : 51.281643 Content Loss: 5.612019
# run [100]: Style Loss : 18.135159 Content Loss: 5.841838
# run [150]: Style Loss : 7.778915 Content Loss: 5.841946
# run [200]: Style Loss : 2.244286 Content Loss: 5.764289
# run [250]: Style Loss : 0.953763 Content Loss: 5.602705
# run [300]: Style Loss : 0.688355 Content Loss: 5.340081
# 74.40591883659363
# Starting style transfer!!
# run [50]: Style Loss : 52.434307 Content Loss: 4.795054
# run [100]: Style Loss : 20.559858 Content Loss: 5.203890
# run [150]: Style Loss : 8.679394 Content Loss: 5.439759
# run [200]: Style Loss : 3.079365 Content Loss: 5.574732
# run [250]: Style Loss : 1.835490 Content Loss: 5.543602
# run [300]: Style Loss : 1.380874 Content Loss: 5.384291
# 74.59746789932251
# Starting style transfer!!
# run [50]: Style Loss : 356.545166 Content Loss: 8.665031
# run [100]: Style Loss : 87.664169 Content Loss: 9.237921
# run [150]: Style Loss : 39.687946 Content Loss: 9.524824
# run [200]: Style Loss : 21.234219 Content Loss: 9.689584
# run [250]: Style Loss : 14.501627 Content Loss: 9.802019
# run [300]: Style Loss : 8.475340 Content Loss: 9.870922
# 74.84061574935913
# Starting style transfer!!
# run [50]: Style Loss : 18.698214 Content Loss: 1.767781
# run [100]: Style Loss : 6.193997 Content Loss: 2.032419
# run [150]: Style Loss : 1.837577 Content Loss: 2.118844
# run [200]: Style Loss : 1.060576 Content Loss: 2.056811
# run [250]: Style Loss : 0.857963 Content Loss: 1.996313
# run [300]: Style Loss : 0.738134 Content Loss: 1.966745
# 74.60511088371277
# Starting style transfer!!
# run [50]: Style Loss : 38.259796 Content Loss: 4.597849
# run [100]: Style Loss : 9.613675 Content Loss: 4.960706
# run [150]: Style Loss : 3.970312 Content Loss: 4.988892
# run [200]: Style Loss : 2.438930 Content Loss: 4.899605
# run [250]: Style Loss : 1.736353 Content Loss: 4.814805
# run [300]: Style Loss : 1.356154 Content Loss: 4.733211
# 74.46493911743164
# Starting style transfer!!
# run [50]: Style Loss : 160.157562 Content Loss: 10.315546
# run [100]: Style Loss : 51.854912 Content Loss: 10.753061
# run [150]: Style Loss : 22.300390 Content Loss: 10.933411
# run [200]: Style Loss : 11.816862 Content Loss: 10.994957
# run [250]: Style Loss : 6.359311 Content Loss: 10.983412
# run [300]: Style Loss : 3.849749 Content Loss: 10.919858
# 74.53802108764648
# Starting style transfer!!
# run [50]: Style Loss : 70.759277 Content Loss: 11.093770
# run [100]: Style Loss : 23.698740 Content Loss: 11.112026
# run [150]: Style Loss : 12.010942 Content Loss: 10.923346
# run [200]: Style Loss : 4.567446 Content Loss: 10.627673
# run [250]: Style Loss : 1.664663 Content Loss: 10.361293
# run [300]: Style Loss : 1.026262 Content Loss: 10.085846
# 74.40171837806702
# Starting style transfer!!
# run [50]: Style Loss : 84.257141 Content Loss: 6.190892
# run [100]: Style Loss : 28.422462 Content Loss: 6.649620
# run [150]: Style Loss : 13.103993 Content Loss: 6.743130
# run [200]: Style Loss : 5.899001 Content Loss: 6.775806
# run [250]: Style Loss : 3.580182 Content Loss: 6.709493
# run [300]: Style Loss : 2.770579 Content Loss: 6.546010
# 74.6165759563446
# Starting style transfer!!
# run [50]: Style Loss : 18.085564 Content Loss: 2.623906
# run [100]: Style Loss : 4.454649 Content Loss: 2.739031
# run [150]: Style Loss : 1.669799 Content Loss: 2.575501
# run [200]: Style Loss : 1.113971 Content Loss: 2.421137
# run [250]: Style Loss : 0.868701 Content Loss: 2.290050
# run [300]: Style Loss : 0.654121 Content Loss: 2.234887
# 74.54235982894897
# Starting style transfer!!
# run [50]: Style Loss : 14.119733 Content Loss: 2.080892
# run [100]: Style Loss : 1.304228 Content Loss: 1.636243
# run [150]: Style Loss : 0.371926 Content Loss: 1.305981
# run [200]: Style Loss : 0.251784 Content Loss: 1.210333
# run [250]: Style Loss : 0.159891 Content Loss: 1.176765
# run [300]: Style Loss : 0.097135 Content Loss: 1.155645
# 74.38498663902283
# Starting style transfer!!
# run [50]: Style Loss : 72.128899 Content Loss: 9.071254
# run [100]: Style Loss : 23.102938 Content Loss: 9.302054
# run [150]: Style Loss : 9.161970 Content Loss: 9.376614
# run [200]: Style Loss : 3.078815 Content Loss: 9.425542
# run [250]: Style Loss : 1.660794 Content Loss: 9.391205
# run [300]: Style Loss : 1.129798 Content Loss: 9.232480
# 74.48246884346008
# Starting style transfer!!
# run [50]: Style Loss : 61.655128 Content Loss: 4.900538
# run [100]: Style Loss : 25.191011 Content Loss: 5.266466
# run [150]: Style Loss : 10.475311 Content Loss: 5.400816
# run [200]: Style Loss : 2.855657 Content Loss: 5.469151
# run [250]: Style Loss : 1.193115 Content Loss: 5.450783
# run [300]: Style Loss : 0.789217 Content Loss: 5.312883
# 74.71178483963013
# Starting style transfer!!
# run [50]: Style Loss : 44.735672 Content Loss: 3.425976
# run [100]: Style Loss : 15.928666 Content Loss: 3.758040
# run [150]: Style Loss : 8.190653 Content Loss: 3.836246
# run [200]: Style Loss : 4.830467 Content Loss: 3.812637
# run [250]: Style Loss : 3.044353 Content Loss: 3.803856
# run [300]: Style Loss : 2.412409 Content Loss: 3.757871
# 74.46989464759827
# Starting style transfer!!
# run [50]: Style Loss : 154.184402 Content Loss: 4.464672
# run [100]: Style Loss : 41.227139 Content Loss: 5.039412
# run [150]: Style Loss : 21.504341 Content Loss: 5.161107
# run [200]: Style Loss : 11.715421 Content Loss: 5.259910
# run [250]: Style Loss : 6.442214 Content Loss: 5.388328
# run [300]: Style Loss : 4.315417 Content Loss: 5.397147
# 74.3753137588501
# Starting style transfer!!
# run [50]: Style Loss : 119.316139 Content Loss: 12.264456
# run [100]: Style Loss : 26.436277 Content Loss: 12.395918
# run [150]: Style Loss : 11.676265 Content Loss: 12.305285
# run [200]: Style Loss : 6.623561 Content Loss: 12.145916
# run [250]: Style Loss : 4.159544 Content Loss: 11.902489
# run [300]: Style Loss : 2.701160 Content Loss: 11.609177
# 74.5628170967102
# Starting style transfer!!
# run [50]: Style Loss : 27.439619 Content Loss: 4.019941
# run [100]: Style Loss : 5.116870 Content Loss: 4.196463
# run [150]: Style Loss : 2.121021 Content Loss: 4.074414
# run [200]: Style Loss : 0.920556 Content Loss: 3.937786
# run [250]: Style Loss : 0.699587 Content Loss: 3.797536
# run [300]: Style Loss : 0.577881 Content Loss: 3.675272
# 74.63542914390564
# Starting style transfer!!
# run [50]: Style Loss : 184.349167 Content Loss: 11.990219
# run [100]: Style Loss : 41.358875 Content Loss: 12.024454
# run [150]: Style Loss : 14.631104 Content Loss: 11.942119
# run [200]: Style Loss : 7.214723 Content Loss: 11.821280
# run [250]: Style Loss : 4.528071 Content Loss: 11.668630
# run [300]: Style Loss : 3.146414 Content Loss: 11.458937
# 74.44470024108887
# Starting style transfer!!
# run [50]: Style Loss : 99.043655 Content Loss: 9.833229
# run [100]: Style Loss : 37.365067 Content Loss: 10.012000
# run [150]: Style Loss : 17.605818 Content Loss: 10.089156
# run [200]: Style Loss : 6.366905 Content Loss: 10.204054
# run [250]: Style Loss : 3.014460 Content Loss: 10.238803
# run [300]: Style Loss : 2.283911 Content Loss: 10.271529
# 74.72075629234314
# Starting style transfer!!
# run [50]: Style Loss : 59.777626 Content Loss: 3.131365
# run [100]: Style Loss : 10.827616 Content Loss: 3.751635
# run [150]: Style Loss : 1.233634 Content Loss: 3.753220
# run [200]: Style Loss : 0.663835 Content Loss: 3.278728
# run [250]: Style Loss : 0.500119 Content Loss: 2.966350
# run [300]: Style Loss : 0.411221 Content Loss: 2.775908
# 74.48400568962097
# Starting style transfer!!
# run [50]: Style Loss : 44.203056 Content Loss: 6.461102
# run [100]: Style Loss : 14.957468 Content Loss: 6.745767
# run [150]: Style Loss : 7.232445 Content Loss: 6.880281
# run [200]: Style Loss : 4.307563 Content Loss: 6.929452
# run [250]: Style Loss : 3.200776 Content Loss: 6.926837
# run [300]: Style Loss : 2.592696 Content Loss: 6.899715
# 74.62718534469604
# Starting style transfer!!
# run [50]: Style Loss : 134.512024 Content Loss: 10.073470
# run [100]: Style Loss : 26.959324 Content Loss: 10.080812
# run [150]: Style Loss : 11.295116 Content Loss: 10.003042
# run [200]: Style Loss : 6.323072 Content Loss: 9.834315
# run [250]: Style Loss : 4.114060 Content Loss: 9.676341
# run [300]: Style Loss : 4.365280 Content Loss: 9.496343
# 74.43086004257202
# Starting style transfer!!
# run [50]: Style Loss : 60.558334 Content Loss: 3.175602
# run [100]: Style Loss : 27.110001 Content Loss: 3.629255
# run [150]: Style Loss : 7.801949 Content Loss: 3.947162
# run [200]: Style Loss : 3.224017 Content Loss: 4.021763
# run [250]: Style Loss : 2.326605 Content Loss: 3.818459
# run [300]: Style Loss : 2.020256 Content Loss: 3.624576
# 74.63196086883545
# Starting style transfer!!
# run [50]: Style Loss : 14.853722 Content Loss: 2.276547
# run [100]: Style Loss : 4.779867 Content Loss: 2.495788
# run [150]: Style Loss : 2.356812 Content Loss: 2.571451
# run [200]: Style Loss : 1.496666 Content Loss: 2.585210
# run [250]: Style Loss : 1.164021 Content Loss: 2.562147
# run [300]: Style Loss : 0.994042 Content Loss: 2.537022
# 74.60776352882385
# Starting style transfer!!
# run [50]: Style Loss : 44.303993 Content Loss: 3.685397
# run [100]: Style Loss : 10.779665 Content Loss: 3.982181
# run [150]: Style Loss : 4.682325 Content Loss: 4.070797
# run [200]: Style Loss : 2.596185 Content Loss: 4.100801
# run [250]: Style Loss : 1.716423 Content Loss: 4.077694
# run [300]: Style Loss : 1.352226 Content Loss: 4.032301
# 74.26963686943054
# Starting style transfer!!
# run [50]: Style Loss : 66.278915 Content Loss: 3.092561
# run [100]: Style Loss : 30.308182 Content Loss: 3.514384
# run [150]: Style Loss : 10.850166 Content Loss: 3.799812
# run [200]: Style Loss : 4.690868 Content Loss: 3.913044
# run [250]: Style Loss : 3.399009 Content Loss: 3.842399
# run [300]: Style Loss : 2.817540 Content Loss: 3.676691
# 74.55526638031006
# Starting style transfer!!
# run [50]: Style Loss : 19.699879 Content Loss: 2.438499
# run [100]: Style Loss : 5.176547 Content Loss: 2.490143
# run [150]: Style Loss : 2.070728 Content Loss: 2.442616
# run [200]: Style Loss : 1.267039 Content Loss: 2.345426
# run [250]: Style Loss : 0.930776 Content Loss: 2.271049
# run [300]: Style Loss : 0.735605 Content Loss: 2.227914
# 74.78641080856323
# Starting style transfer!!
# run [50]: Style Loss : 48.640301 Content Loss: 4.054446
# run [100]: Style Loss : 15.343177 Content Loss: 4.312528
# run [150]: Style Loss : 4.583839 Content Loss: 4.351054
# run [200]: Style Loss : 1.146614 Content Loss: 4.329690
# run [250]: Style Loss : 0.666291 Content Loss: 4.113273
# run [300]: Style Loss : 0.559355 Content Loss: 3.929651
# 74.53532576560974
# Starting style transfer!!
# run [50]: Style Loss : 59.773941 Content Loss: 7.237873
# run [100]: Style Loss : 18.748573 Content Loss: 7.287089
# run [150]: Style Loss : 10.487976 Content Loss: 7.138573
# run [200]: Style Loss : 5.120136 Content Loss: 6.925188
# run [250]: Style Loss : 2.582287 Content Loss: 6.726921
# run [300]: Style Loss : 1.939596 Content Loss: 6.510932
# 74.62704873085022
# Starting style transfer!!
# run [50]: Style Loss : 79.227417 Content Loss: 4.701507
# run [100]: Style Loss : 21.865173 Content Loss: 5.138139
# run [150]: Style Loss : 11.199080 Content Loss: 5.209007
# run [200]: Style Loss : 5.466767 Content Loss: 5.314255
# run [250]: Style Loss : 3.381463 Content Loss: 5.374424
# run [300]: Style Loss : 2.640147 Content Loss: 5.331861
# 74.45556449890137
# Starting style transfer!!
# run [50]: Style Loss : 163.487396 Content Loss: 7.790763
# run [100]: Style Loss : 57.360725 Content Loss: 8.336912
# run [150]: Style Loss : 28.116158 Content Loss: 8.549757
# run [200]: Style Loss : 15.691512 Content Loss: 8.649035
# run [250]: Style Loss : 8.483570 Content Loss: 8.710413
# run [300]: Style Loss : 4.771282 Content Loss: 8.716724
# 74.53819251060486
# Starting style transfer!!
# run [50]: Style Loss : 44.663620 Content Loss: 4.860333
# run [100]: Style Loss : 17.083635 Content Loss: 5.196031
# run [150]: Style Loss : 5.401624 Content Loss: 5.351285
# run [200]: Style Loss : 3.037660 Content Loss: 5.274597
# run [250]: Style Loss : 2.259003 Content Loss: 5.056376
# run [300]: Style Loss : 1.696722 Content Loss: 4.906201
# 74.67824816703796
# Starting style transfer!!
# run [50]: Style Loss : 102.566994 Content Loss: 3.361432
# run [100]: Style Loss : 37.119518 Content Loss: 3.658825
# run [150]: Style Loss : 14.004445 Content Loss: 3.317544
# run [200]: Style Loss : 1.788839 Content Loss: 3.160943
# run [250]: Style Loss : 0.777591 Content Loss: 2.796417
# run [300]: Style Loss : 0.530246 Content Loss: 2.515373
# 74.55396842956543
# Starting style transfer!!
# run [50]: Style Loss : 31.644138 Content Loss: 5.088596
# run [100]: Style Loss : 12.035082 Content Loss: 5.349273
# run [150]: Style Loss : 4.079833 Content Loss: 5.422994
# run [200]: Style Loss : 1.818153 Content Loss: 5.419282
# run [250]: Style Loss : 1.223131 Content Loss: 5.240551
# run [300]: Style Loss : 1.003253 Content Loss: 5.061512
# 74.47752332687378
# Starting style transfer!!
# run [50]: Style Loss : 80.868843 Content Loss: 3.262918
# run [100]: Style Loss : 40.897907 Content Loss: 3.764197
# run [150]: Style Loss : 12.269958 Content Loss: 4.200770
# run [200]: Style Loss : 2.184770 Content Loss: 4.351324
# run [250]: Style Loss : 0.836144 Content Loss: 4.086036
# run [300]: Style Loss : 0.611248 Content Loss: 3.709634
# 74.59363746643066
# Starting style transfer!!
# run [50]: Style Loss : 189.541000 Content Loss: 2.636160
# run [100]: Style Loss : 55.747253 Content Loss: 3.111344
# run [150]: Style Loss : 20.708988 Content Loss: 3.195576
# run [200]: Style Loss : 3.407557 Content Loss: 3.220144
# run [250]: Style Loss : 1.373290 Content Loss: 2.835394
# run [300]: Style Loss : 0.931707 Content Loss: 2.497736
# 74.70577955245972
# Starting style transfer!!
# run [50]: Style Loss : 12.805935 Content Loss: 2.531797
# run [100]: Style Loss : 4.469738 Content Loss: 2.683238
# run [150]: Style Loss : 0.982088 Content Loss: 2.721203
# run [200]: Style Loss : 0.504397 Content Loss: 2.558949
# run [250]: Style Loss : 0.412387 Content Loss: 2.426863
# run [300]: Style Loss : 0.360117 Content Loss: 2.351372
# 74.66465282440186
# Starting style transfer!!
# run [50]: Style Loss : 46.197285 Content Loss: 3.635542
# run [100]: Style Loss : 17.357710 Content Loss: 4.002766
# run [150]: Style Loss : 2.947350 Content Loss: 4.097382
# run [200]: Style Loss : 0.866187 Content Loss: 3.935312
# run [250]: Style Loss : 0.629782 Content Loss: 3.580151
# run [300]: Style Loss : 0.525421 Content Loss: 3.378182
# 74.4792320728302
# Starting style transfer!!
# run [50]: Style Loss : 23.886616 Content Loss: 2.699367
# run [100]: Style Loss : 5.671027 Content Loss: 2.819672
# run [150]: Style Loss : 1.109044 Content Loss: 2.736746
# run [200]: Style Loss : 0.609220 Content Loss: 2.579387
# run [250]: Style Loss : 0.477213 Content Loss: 2.439213
# run [300]: Style Loss : 0.396885 Content Loss: 2.360662
# 74.5967321395874
# Starting style transfer!!
# run [50]: Style Loss : 62.379559 Content Loss: 8.532333
# run [100]: Style Loss : 20.210546 Content Loss: 8.715927
# run [150]: Style Loss : 8.378865 Content Loss: 8.733717
# ...
# run [250]: Style Loss : 3.663313 Content Loss: 5.445312
# run [300]: Style Loss : 1.438818 Content Loss: 5.298585
# 74.4837555885315
# Starting style transfer!!
# run [50]: Style Loss : 50.178055 Content Loss: 2.641660
# run [100]: Style Loss : 17.068045 Content Loss: 2.942361
# run [150]: Style Loss : 5.934705 Content Loss: 2.951940
# run [200]: Style Loss : 3.815652 Content Loss: 2.779628
# run [250]: Style Loss : 2.595787 Content Loss: 2.644045
# run [300]: Style Loss : 1.657130 Content Loss: 2.572775
# 74.49916124343872
# Starting style transfer!!
# run [50]: Style Loss : 91.031181 Content Loss: 3.311565
# run [100]: Style Loss : 23.502792 Content Loss: 3.698335
# run [150]: Style Loss : 10.210585 Content Loss: 3.601788
# run [200]: Style Loss : 2.913990 Content Loss: 3.503196
# run [250]: Style Loss : 0.781731 Content Loss: 3.388063
# run [300]: Style Loss : 0.496988 Content Loss: 3.226535
# 74.6450686454773
# Starting style transfer!!
# run [50]: Style Loss : 203.290787 Content Loss: 2.852795
# run [100]: Style Loss : 97.884018 Content Loss: 3.186560
# run [150]: Style Loss : 32.641251 Content Loss: 3.341087
# run [200]: Style Loss : 3.727062 Content Loss: 3.530090
# run [250]: Style Loss : 1.176570 Content Loss: 3.229176
# run [300]: Style Loss : 0.700947 Content Loss: 2.897022
# 74.58127546310425
# Starting style transfer!!
# run [50]: Style Loss : 166.011810 Content Loss: 3.958527
# run [100]: Style Loss : 66.427933 Content Loss: 4.353689
# run [150]: Style Loss : 27.594275 Content Loss: 4.448479
# run [200]: Style Loss : 3.968724 Content Loss: 4.709380
# run [250]: Style Loss : 1.461560 Content Loss: 4.502169
# run [300]: Style Loss : 0.962056 Content Loss: 4.093692
# 74.44797658920288
# Starting style transfer!!
# run [50]: Style Loss : 101.079788 Content Loss: 2.688948
# run [100]: Style Loss : 15.551851 Content Loss: 3.144835
# run [150]: Style Loss : 1.193960 Content Loss: 2.847156
# run [200]: Style Loss : 0.541284 Content Loss: 2.506910
# run [250]: Style Loss : 0.305149 Content Loss: 2.388733
# run [300]: Style Loss : 0.212286 Content Loss: 2.321535
# 74.4811577796936
# Starting style transfer!!
# run [50]: Style Loss : 129.706863 Content Loss: 3.686957
# run [100]: Style Loss : 47.443264 Content Loss: 4.094620
# run [150]: Style Loss : 15.213084 Content Loss: 4.316578
# run [200]: Style Loss : 3.576536 Content Loss: 4.244503
# run [250]: Style Loss : 1.717178 Content Loss: 3.835746
# run [300]: Style Loss : 1.236640 Content Loss: 3.468274
# 75.06523966789246
# Starting style transfer!!
# run [50]: Style Loss : 217.234482 Content Loss: 4.589398
# run [100]: Style Loss : 54.024811 Content Loss: 5.343060
# run [150]: Style Loss : 26.548576 Content Loss: 5.294895
# run [200]: Style Loss : 13.922433 Content Loss: 5.280226
# run [250]: Style Loss : 5.245158 Content Loss: 5.312476
# run [300]: Style Loss : 1.709592 Content Loss: 5.240611
# 74.65947413444519
# Starting style transfer!!
# run [50]: Style Loss : 111.107895 Content Loss: 3.132624
# run [100]: Style Loss : 43.983303 Content Loss: 3.295038
# run [150]: Style Loss : 10.296280 Content Loss: 3.493758
# run [200]: Style Loss : 3.043983 Content Loss: 3.433342
# run [250]: Style Loss : 1.800695 Content Loss: 3.039254
# run [300]: Style Loss : 1.308294 Content Loss: 2.789701
# 74.7553071975708
# Starting style transfer!!
# run [50]: Style Loss : 202.708450 Content Loss: 4.512523
# run [100]: Style Loss : 56.292095 Content Loss: 5.073225
# run [150]: Style Loss : 28.350973 Content Loss: 5.190381
# run [200]: Style Loss : 10.307570 Content Loss: 5.423789
# run [250]: Style Loss : 3.216490 Content Loss: 5.537262
# run [300]: Style Loss : 1.857414 Content Loss: 5.445693
# 74.90236735343933
# Starting style transfer!!
# run [50]: Style Loss : 39.065491 Content Loss: 1.982836
# run [100]: Style Loss : 9.057187 Content Loss: 1.871740
# run [150]: Style Loss : 0.463733 Content Loss: 1.609485
# run [200]: Style Loss : 0.272277 Content Loss: 1.147031
# run [250]: Style Loss : 0.212837 Content Loss: 0.956690
# run [300]: Style Loss : 0.179683 Content Loss: 0.873735
# 74.78458857536316
# Starting style transfer!!
# run [50]: Style Loss : 74.530602 Content Loss: 1.835141
# run [100]: Style Loss : 3.255478 Content Loss: 2.117630
# run [150]: Style Loss : 0.166351 Content Loss: 1.529277
# run [200]: Style Loss : 0.072091 Content Loss: 1.339281
# run [250]: Style Loss : 0.058982 Content Loss: 1.281980
# run [300]: Style Loss : 0.053130 Content Loss: 1.259516
# 74.68386507034302
# Starting style transfer!!
# run [50]: Style Loss : 82.996796 Content Loss: 2.499064
# run [100]: Style Loss : 17.065639 Content Loss: 2.763227
# run [150]: Style Loss : 1.214243 Content Loss: 2.423228
# run [200]: Style Loss : 0.258747 Content Loss: 1.814029
# run [250]: Style Loss : 0.151996 Content Loss: 1.434368
# run [300]: Style Loss : 0.121523 Content Loss: 1.235515
# 74.48113203048706
# Starting style transfer!!
# run [50]: Style Loss : 189.409042 Content Loss: 5.137376
# run [100]: Style Loss : 52.321342 Content Loss: 5.530291
# run [150]: Style Loss : 26.514477 Content Loss: 5.453125
# run [200]: Style Loss : 8.308706 Content Loss: 5.420005
# run [250]: Style Loss : 1.764516 Content Loss: 5.342566
# run [300]: Style Loss : 0.950263 Content Loss: 4.989390
# 74.58111333847046
# Starting style transfer!!
# run [50]: Style Loss : 268.558868 Content Loss: 4.584730
# run [100]: Style Loss : 102.627411 Content Loss: 4.817209
# run [150]: Style Loss : 38.815479 Content Loss: 5.279345
# run [200]: Style Loss : 10.892123 Content Loss: 5.677213
# run [250]: Style Loss : 8062.826660 Content Loss: 8.601824
# run [300]: Style Loss :  nan Content Loss:  nan
# 74.6028139591217
# Starting style transfer!!
# run [50]: Style Loss : 24.380939 Content Loss: 1.917998
# run [100]: Style Loss : 3.084197 Content Loss: 1.728806
# run [150]: Style Loss : 0.410149 Content Loss: 1.404730
# run [200]: Style Loss : 0.292860 Content Loss: 1.216752
# run [250]: Style Loss : 0.228430 Content Loss: 1.131103
# run [300]: Style Loss : 0.189672 Content Loss: 1.089972
# 74.72961354255676
# Starting style transfer!!
# run [50]: Style Loss : 423.557220 Content Loss: 7.183160
# run [100]: Style Loss : 187.754532 Content Loss: 7.824231
# run [150]: Style Loss : 97.308456 Content Loss: 8.157581
# run [200]: Style Loss : 59.913456 Content Loss: 8.288713
# run [250]: Style Loss : 35.199020 Content Loss: 8.445036
# run [300]: Style Loss : 16.161987 Content Loss: 8.512378
# 74.63964009284973
# Starting style transfer!!
# run [50]: Style Loss : 53.405739 Content Loss: 6.756555
# run [100]: Style Loss : 21.933716 Content Loss: 6.642735
# run [150]: Style Loss : 4.212981 Content Loss: 6.430047
# run [200]: Style Loss : 0.942226 Content Loss: 6.143414
# run [250]: Style Loss : 0.559655 Content Loss: 5.683092
# run [300]: Style Loss : 0.474449 Content Loss: 5.246091
# 74.52837586402893
# Starting style transfer!!
# run [50]: Style Loss : 14.800968 Content Loss: 2.246660
# run [100]: Style Loss : 1.094332 Content Loss: 2.180147
# run [150]: Style Loss : 0.415994 Content Loss: 2.046355
# run [200]: Style Loss : 0.239462 Content Loss: 2.001417
# run [250]: Style Loss : 0.168114 Content Loss: 1.979336
# run [300]: Style Loss : 0.144451 Content Loss: 1.969699
# 74.61522316932678
# Starting style transfer!!
# run [50]: Style Loss : 62.362164 Content Loss: 13.560009
# run [100]: Style Loss : 12.445408 Content Loss: 13.427110
# run [150]: Style Loss : 5.556363 Content Loss: 13.173859
# run [200]: Style Loss : 2.991671 Content Loss: 12.790049
# run [250]: Style Loss : 1.855084 Content Loss: 12.448671
# run [300]: Style Loss : 1.491783 Content Loss: 12.135297
# 74.43876838684082
# Starting style transfer!!
# run [50]: Style Loss : 42.680382 Content Loss: 3.016829
# run [100]: Style Loss : 7.789213 Content Loss: 2.787225
# run [150]: Style Loss : 3.779603 Content Loss: 2.553726
# run [200]: Style Loss : 2.378940 Content Loss: 2.401006
# run [250]: Style Loss : 1.933352 Content Loss: 2.268243
# run [300]: Style Loss : 1.563552 Content Loss: 2.183040
# 74.82843708992004
# Starting style transfer!!
# run [50]: Style Loss : 199.397964 Content Loss: 3.845416
# run [100]: Style Loss : 110.831421 Content Loss: 4.554973
# run [150]: Style Loss : 46.281242 Content Loss: 4.864614
# run [200]: Style Loss : 10.427812 Content Loss: 5.124238
# run [250]: Style Loss : 2.881378 Content Loss: 5.141203
# run [300]: Style Loss : 1.452732 Content Loss: 4.623522
# 74.73586130142212
# Starting style transfer!!
# run [50]: Style Loss : 8.059889 Content Loss: 2.782370
# run [100]: Style Loss : 2.661764 Content Loss: 2.870232
# run [150]: Style Loss : 1.338720 Content Loss: 2.734658
# run [200]: Style Loss : 0.965568 Content Loss: 2.581073
# run [250]: Style Loss : 0.821157 Content Loss: 2.453853
# run [300]: Style Loss : 0.668562 Content Loss: 2.387222
# 74.4668436050415
# Starting style transfer!!
# run [50]: Style Loss : 112.682251 Content Loss: 3.352885
# run [100]: Style Loss : 48.888283 Content Loss: 3.477995
# run [150]: Style Loss : 17.267681 Content Loss: 3.423071
# run [200]: Style Loss : 2.070754 Content Loss: 3.502540
# run [250]: Style Loss : 0.820569 Content Loss: 3.075631
# run [300]: Style Loss : 0.581049 Content Loss: 2.736572
# 74.77925562858582
# Starting style transfer!!
# run [50]: Style Loss : 136.484833 Content Loss: 3.078568
# run [100]: Style Loss : 56.383869 Content Loss: 3.644702
# run [150]: Style Loss : 6.846789 Content Loss: 4.068621
# run [200]: Style Loss : 1.155671 Content Loss: 3.800478
# run [250]: Style Loss : 0.666196 Content Loss: 3.183676
# run [300]: Style Loss : 0.437968 Content Loss: 2.831047
# 75.25541424751282
# Starting style transfer!!
# run [50]: Style Loss : 109.365982 Content Loss: 2.796277
# run [100]: Style Loss : 34.783318 Content Loss: 3.501286
# run [150]: Style Loss : 4.189215 Content Loss: 3.784556
# run [200]: Style Loss : 1.018688 Content Loss: 3.525310
# run [250]: Style Loss : 0.653499 Content Loss: 3.090798
# run [300]: Style Loss : 0.531629 Content Loss: 2.834277
# 74.96405267715454
# Starting style transfer!!
# run [50]: Style Loss : 142.482330 Content Loss: 6.637351
# run [100]: Style Loss : 44.586285 Content Loss: 6.927176
# run [150]: Style Loss : 25.077896 Content Loss: 6.918162
# run [200]: Style Loss : 12.858117 Content Loss: 6.898909
# run [250]: Style Loss : 6.189245 Content Loss: 6.840775
# run [300]: Style Loss : 3.348428 Content Loss: 6.723522
# 74.89010334014893
# Starting style transfer!!
# run [50]: Style Loss : 55.722427 Content Loss: 2.096103
# run [100]: Style Loss : 14.628374 Content Loss: 2.613193
# run [150]: Style Loss : 11.675881 Content Loss: 2.567826
# run [200]: Style Loss : 13.619564 Content Loss: 2.611341
# run [250]: Style Loss : 10.296242 Content Loss: 2.786096
# run [300]: Style Loss : 10.330885 Content Loss: 2.773369
# 75.04706239700317
# Starting style transfer!!
# run [50]: Style Loss : 131.775757 Content Loss: 3.208557
# run [100]: Style Loss : 56.992649 Content Loss: 3.118244
# run [150]: Style Loss : 6.110771 Content Loss: 3.117742
# run [200]: Style Loss : 0.531807 Content Loss: 2.684405
# run [250]: Style Loss : 0.280109 Content Loss: 2.272377
# run [300]: Style Loss : 0.191246 Content Loss: 2.081079
# 75.27698588371277
# Starting style transfer!!
# run [50]: Style Loss : 115.933014 Content Loss: 4.778596
# run [100]: Style Loss : 31.529303 Content Loss: 4.949111
# run [150]: Style Loss : 11.222895 Content Loss: 4.995848
# run [200]: Style Loss : 2.590959 Content Loss: 4.968158
# run [250]: Style Loss : 1.038775 Content Loss: 4.670495
# run [300]: Style Loss : 0.763506 Content Loss: 4.376580
# 74.99229907989502
# Starting style transfer!!
# run [50]: Style Loss : 155.089340 Content Loss: 3.108941
# run [100]: Style Loss : 83.901283 Content Loss: 3.742612
# run [150]: Style Loss : 35.231468 Content Loss: 4.218906
# run [200]: Style Loss : 10.606318 Content Loss: 4.586325
# run [250]: Style Loss : 6.016983 Content Loss: 4.698825
# run [300]: Style Loss : 3.916662 Content Loss: 4.531010
# 74.63844513893127
# Starting style transfer!!
# run [50]: Style Loss : 69.315987 Content Loss: 2.097819
# run [100]: Style Loss : 8.633823 Content Loss: 2.634389
# run [150]: Style Loss : 1.433386 Content Loss: 2.207140
# run [200]: Style Loss : 1.052663 Content Loss: 1.809188
# run [250]: Style Loss : 0.868762 Content Loss: 1.553360
# run [300]: Style Loss : 0.741009 Content Loss: 1.412410
# 74.84697532653809
# Starting style transfer!!
# run [50]: Style Loss : 100.871315 Content Loss: 1.751082
# run [100]: Style Loss : 24.814558 Content Loss: 2.412522
# run [150]: Style Loss : 1.760225 Content Loss: 2.589550
# run [200]: Style Loss : 0.533994 Content Loss: 2.248590
# run [250]: Style Loss : 0.382692 Content Loss: 1.950829
# run [300]: Style Loss : 0.332617 Content Loss: 1.792325
# 75.09678220748901
# Starting style transfer!!
# run [50]: Style Loss : 126.094040 Content Loss: 2.609637
# run [100]: Style Loss : 43.672943 Content Loss: 2.913722
# run [150]: Style Loss : 3.319089 Content Loss: 2.907628
# run [200]: Style Loss : 0.807502 Content Loss: 2.407283
# run [250]: Style Loss : 0.439097 Content Loss: 2.000140
# run [300]: Style Loss : 0.302492 Content Loss: 1.783533
# 74.97777557373047
# Starting style transfer!!
# run [50]: Style Loss : 32.053318 Content Loss: 2.882054
# run [100]: Style Loss : 9.966316 Content Loss: 2.856205
# run [150]: Style Loss : 3.851335 Content Loss: 2.902949
# run [200]: Style Loss : 2.538718 Content Loss: 2.770809
# run [250]: Style Loss : 1.682037 Content Loss: 2.693443
# run [300]: Style Loss : 1.204363 Content Loss: 2.642946
# 74.8749463558197
# Starting style transfer!!
# run [50]: Style Loss : 129.068024 Content Loss: 3.403609
# run [100]: Style Loss : 68.597496 Content Loss: 3.999713
# run [150]: Style Loss : 36.641823 Content Loss: 4.187621
# run [200]: Style Loss : 8.890248 Content Loss: 4.408991
# run [250]: Style Loss : 2.926771 Content Loss: 4.369885
# run [300]: Style Loss : 1.863712 Content Loss: 4.071108
# 74.9080216884613
# Starting style transfer!!
# run [50]: Style Loss : 159.636398 Content Loss: 3.227946
# run [100]: Style Loss : 73.512177 Content Loss: 3.256363
# run [150]: Style Loss : 19.017109 Content Loss: 3.486669
# run [200]: Style Loss : 1.852960 Content Loss: 3.468706
# run [250]: Style Loss : 0.835644 Content Loss: 3.010933
# run [300]: Style Loss : 0.587479 Content Loss: 2.729945
# 75.06028771400452
# Starting style transfer!!
# run [50]: Style Loss : 72.881119 Content Loss: 8.639787
# run [100]: Style Loss : 39.113277 Content Loss: 8.508677
# run [150]: Style Loss : 15.802483 Content Loss: 8.336878
# run [200]: Style Loss : 3.604818 Content Loss: 8.158829
# run [250]: Style Loss : 1.119909 Content Loss: 7.892102
# run [300]: Style Loss : 0.690855 Content Loss: 7.404328
# 74.83710670471191
# Starting style transfer!!
# run [50]: Style Loss : 22.323294 Content Loss: 1.714516
# run [100]: Style Loss : 2.530862 Content Loss: 1.942456
# run [150]: Style Loss : 0.529762 Content Loss: 1.522143
# run [200]: Style Loss : 0.377802 Content Loss: 1.305765
# run [250]: Style Loss : 0.319261 Content Loss: 1.210172
# run [300]: Style Loss : 0.276536 Content Loss: 1.167186
# 75.0236120223999
# Starting style transfer!!
# run [50]: Style Loss : 37.205391 Content Loss: 3.841581
# run [100]: Style Loss : 11.833718 Content Loss: 4.126510
# run [150]: Style Loss : 4.006869 Content Loss: 4.260928
# run [200]: Style Loss : 1.701036 Content Loss: 4.202065
# run [250]: Style Loss : 1.220592 Content Loss: 4.025691
# run [300]: Style Loss : 0.975905 Content Loss: 3.905799
# 74.80017757415771
# Starting style transfer!!
# run [50]: Style Loss : 187.040329 Content Loss: 3.548134
# run [100]: Style Loss : 74.643929 Content Loss: 3.793107
# run [150]: Style Loss : 25.255232 Content Loss: 3.982885
# run [200]: Style Loss : 6.818385 Content Loss: 3.921671
# run [250]: Style Loss : 1.770410 Content Loss: 3.701362
# run [300]: Style Loss : 0.855359 Content Loss: 3.365800
# 75.01371026039124
# Starting style transfer!!
# run [50]: Style Loss : 57.133888 Content Loss: 5.328236
# run [100]: Style Loss : 22.260635 Content Loss: 5.242552
# run [150]: Style Loss : 9.196124 Content Loss: 4.995849
# run [200]: Style Loss : 2.910165 Content Loss: 4.736780
# run [250]: Style Loss : 1.392686 Content Loss: 4.359428
# run [300]: Style Loss : 1.020687 Content Loss: 4.009177
# 75.00583839416504
# Starting style transfer!!
# run [50]: Style Loss : 70.227028 Content Loss: 5.741868
# run [100]: Style Loss : 21.339401 Content Loss: 5.586004
# run [150]: Style Loss : 13.371602 Content Loss: 5.217797

# %%
for i in range(len(sketches_list)):
  try: 
    content_image_path = "/content/drive/My Drive/Group_Project/1194GoodImages/"
    content_image_path = content_image_path + sketches_list[i]
    style_image_path = "/content/drive/My Drive/Group_Project/1194AbstractImages/"
    style_image_path = style_image_path + style_list[i]

    content_img = image_loader(content_image_path, transform, max_size=imsize)
    style_img = image_loader(style_image_path, transform, shape=[content_img.size(2), content_img.size(3)])
    input_img = content_img.clone()

    cnn = models.vgg19(pretrained=True).features
    if use_cuda:
      cnn = cnn.cuda()

    output,ss ,cs = train_style_transfer(cnn, content_img, style_img, input_img)
    nout = output.squeeze()
    nout = nout.permute(1,2,0)

    output_path = "/content/drive/My Drive/Group_Project/output_good/" + out2_list[i] + '.jpeg'
    torchvision.utils.save_image(nout.permute(2,0,1), output_path)
  except:
    pass

# %%
cnn = models.vgg19(pretrained=True).features

# move it to the GPU if possible:
if use_cuda:
    cnn = cnn.cuda()

# %%
"/content/drive/My Drive/Group_Project/output_good/" + out_list[0] + '.jpeg'
